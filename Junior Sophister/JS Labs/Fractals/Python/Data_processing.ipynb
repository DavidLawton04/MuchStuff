# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Voltages = [3, 5, 7]
Molarities = [1, 0.25, 0.1, 0.01]
data_points = np.meshgrid(Voltages, Molarities)

plt.figure()
plt.plot(data_points[0], data_points[1], 'ro')
plt.yscale('log')
plt.show()

# %%
import os
from scipy import misc
import PIL

# file_path = ['':'/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M3V_Light3_bitmap.bmp', '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M5V_Light0_Invert.bmp', '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M7V_Light3_bitmap.bmp', '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_25M_3V_bitmap.bmp', '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.25M_5V_bitmap.bmp']

path = '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M3V_Light3_bitmap.bmp'

# image= misc.imread('/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M3V_Light3_bitmap.bmp')

image = PIL.Image.open(path)
print(image.format, image.size, image.mode)
image.show()

image = np.array(image)
# for i in range(0, 200):
#     # print(image[i, i])

plt.figure()
plt.imshow(image, cmap='gray')

def mass_dimension(img, tup):
    x, y = tup
    for r in range(1,np.min([x,y])+1):
        q = np.where(img[x-r:x+r, y-r:y+r] == 255)
        proportion = len(q[0])/((2*r)**2)
        print(r, proportion)

# mass_dimension(image, (130, 130))
data_files = [

[0.01, 5, '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals0.01M5V_bitmap.bmp']
[0.25, 3, (187, 189), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_25M_3V_bitmap.bmp']
[0.25, 5, (285, 265), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.25M_5V_bitmap.bmp']
[0.01, 7, '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.01M_7V_bitmap.bmp']
[0.1, 7, (355, 274), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.1M_7V_bitmap.bmp']
[0.1, 5, (295, 149), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.1M_5V_bitmap.bmp']
[0.01, 3, (222,224), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.01M_3V_bitmap.bmp']
[0.1, 3, (159, 156), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractals_0.1M_3V_bitmap.bmp']
[0.25, 7, (251, 229), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal25M7V_light3_bitmap.bmp']
[1, 7, (262, 280), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M7V_Light3_bitmap.bmp']
[1, 5, (242, 180), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M5V_Light0_Invert.bmp']
[1, 3, (196, 170), '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Fractals/fractal images/Fractal1M3V_Light3_bitmap.bmp']

]
# Out:
# BMP (517, 458) L

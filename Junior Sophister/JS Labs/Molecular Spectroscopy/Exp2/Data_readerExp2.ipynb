# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define file paths and names
file_paths = {
    'N2_S_Spectrum': '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Molecular Spectroscopy/Exp2/N2SBigPeaks_FLMS043641_12-47-08-809.txt',
    'N2_S_Spectrum_small': '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Molecular Spectroscopy/Exp2/N2SSmallPeaks_FLMS043641_12-48-40-027.txt',
    'N2_T_Spectrum': '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Molecular Spectroscopy/Exp2/N2TBigPeaks_FLMT016052_12-53-00-515.txt',
    'N2_T_Spectrum_small': '/home/dj-lawton/Documents/Junior Sophister/JS Labs/Molecular Spectroscopy/Exp2/N2TSmallPeaks_FLMT016052_12-54-22-853.txt',
}

# Load the data into a dictionary
data_frames = {name: pd.read_csv(path, delim_whitespace=True, names=['Wavelength', 'Counts']) for name, path in file_paths.items()}

# sorted_data_frames = {name: df.sort_values(by='Counts') for name, df in data_frames.items()}

# Print the data frames
for name, df in data_frames.items():
    print(f"{name}:(Sorted by Count)\n{df}\n")


# Example usage of one of the data frames
for name, df in data_frames.items():
    plt.plot(df['Wavelength'], df['Counts'], label=name)
    plt.xlabel('Wavelength (nm)')
    plt.ylabel('Counts')
    plt.xlim([335, 345])
    plt.show()
    plt.close()
# fig, axs = plt.subplots(2, 2)
# fig.suptitle('$N_2$ Emission Spectra')
# fig.tight_layout(pad=3.0)



# for i, (name, df) in enumerate(data_frames.items()):
#     ax = axs[i//2, i%2]
#     ax.plot(df['Wavelength'], df['Counts'])
#     ax.set_title(name)
#     ax.set_xlabel('Wavelength (nm)')
#     ax.set_ylabel('Counts')
# plt.show()
# Out:
# N2_S_Spectrum:(Sorted by Count)
#       Wavelength    Counts
# 0        340.277  -82.2601
# 1        340.654  -82.2601
# 2        341.032  -82.2601
# 3        341.409 -114.7849
# 4        341.786 -117.9402
# ...          ...       ...
# 2043    1016.709  317.2607
# 2044    1016.989  308.6441
# 2045    1017.269  317.0180
# 2046    1017.549  317.0180
# 2047    1017.829  317.0180
#
# [2048 rows x 2 columns]
#
# N2_S_Spectrum_small:(Sorted by Count)
#       Wavelength    Counts
# 0        340.277 -167.0536
# 1        340.654 -167.0536
# 2        341.032 -167.0536
# 3        341.409 -228.7050
# 4        341.786 -136.9560
# ...          ...       ...
# 2043    1016.709  305.2839
# 2044    1016.989  285.8661
# 2045    1017.269  308.6820
# 2046    1017.549  308.6820
# 2047    1017.829  308.6820
#
# [2048 rows x 2 columns]
#
# N2_T_Spectrum:(Sorted by Count)
#       Wavelength     Counts
# 0        297.849 -1138.5243
# 1        297.920 -1138.5243
# 2        297.991 -1138.5243
# 3        298.062 -1136.1838
# 4        298.133    62.1705
# ...          ...        ...
# 3643     516.482   184.7560
# 3644     516.531    78.5542
# 3645     516.580   172.1757
# 3646     516.629   172.1757
# 3647     516.678   172.1757
#
# [3648 rows x 2 columns]
#
# N2_T_Spectrum_small:(Sorted by Count)
#       Wavelength     Counts
# 0        297.849 -2197.8849
# 1        297.920 -2197.8849
# 2        297.991 -2197.8849
# 3        298.062 -2186.1823
# 4        298.133    58.0989
# ...          ...        ...
# 3643     516.482   357.9801
# 3644     516.531   129.1927
# 3645     516.580   360.9057
# 3646     516.629   360.9057
# 3647     516.678   360.9057
#
# [3648 rows x 2 columns]
